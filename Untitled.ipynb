# %%
import pandas as pd
from pprint import pprint

# %%
df = pd.read_csv("metacritic_movies.csv")
df
# Out:
#               movie_title release_date                         genre  \
# 0     Anatomy of a Murder     1-Jul-59  Drama,Mystery,Thriller,Crime
# 1        Bringing Up Baby    18-Feb-38         Comedy,Romance,Family
# 2              After Life    12-May-99                 Drama,Fantasy
# 3                 Gavagai     3-Aug-18                         Drama
# 4             The Hustler    25-Sep-61                   Drama,Sport
# ...                   ...          ...                           ...
# 9116           Wild Reeds    10-May-95                         Drama
# 9117        No Home Movie     1-Apr-16                   Documentary
# 9118                Solas     8-Sep-00                         Drama
# 9119           J.T. Leroy    26-Apr-19               Biography,Drama
# 9120           Donnybrook    15-Feb-19                         Drama
#
#       meta_mixed  meta_negative  meta_positive  metascore user_mixed  \
# ...

# %%
pprint(df.to_json())
# Out:
# ('{"movie_title":{"0":"Anatomy of a Murder","1":"Bringing Up Baby","2":"After '
#  'Life","3":"Gavagai","4":"The Hustler","5":"The Circus","6":"National '
#  'Gallery","7":"Tales of the Grim Sleeper","8":"The Waiting '
#  'Room","9":"Rosie","10":"Levitated Mass","11":"Nossa Chape","12":"Fiddler: A '
#  'Miracle of Miracles","13":"Liyana","14":"David Crosby: Remember My '
#  'Name","15":"Colliding Dreams","16":"The Order of Myths","17":"House of '
#  'Games","18":"Tickling Giants","19":"Abuse of Weakness","20":"People\'s '
#  'Republic of Desire","21":"The Decline of Western Civilization Part '
#  'III","22":"How to Change the World","23":"Monrovia, Indiana","24":"The Death '
#  'and Life of Marsha P. Johnson","25":"Outside In","26":"3 1\\/2 Minutes, 10 '
#  'Bullets","27":"Keep Quiet","28":"Trees Lounge","29":"Afternoon of a Faun: '
#  'Tanaquil Le Clercq","30":"Promare","31":"Heavy","32":"Charlie\'s '
#  'Country","33":"What Ever Happened to Baby Jane?","34":"Little '
# ...

# %%
dp = pd.read_csv("metacritic_reviews.csv")
dp
# Out:
#                critic_name                         media         movie_title  \
# 0            M. E. Russell            Portland Oregonian       Hustle & Flow
# 1          Owen Gleiberman          Entertainment Weekly       Hustle & Flow
# 2             Ann Hornaday               Washington Post       Hustle & Flow
# 3       Stephanie Zacharek                         Salon       Hustle & Flow
# 4             Jami Bernard           New York Daily News       Hustle & Flow
# ...                    ...                           ...                 ...
# 246950      John Patterson                   L.A. Weekly  The Quiet American
# 246951          Rick Groen  The Globe and Mail (Toronto)  The Quiet American
# 246952    Jonathan Foreman                 New York Post  The Quiet American
# 246953        Jami Bernard           New York Daily News  The Quiet American
# 246954   Stanley Kauffmann              The New Republic  The Quiet American
#
#        review_date  individual_meta_score  \
# ...

# %%
dp.merge(df, how="inner")
# Out:
#                critic_name                         media         movie_title  \
# 0            M. E. Russell            Portland Oregonian       Hustle & Flow
# 1          Owen Gleiberman          Entertainment Weekly       Hustle & Flow
# 2             Ann Hornaday               Washington Post       Hustle & Flow
# 3       Stephanie Zacharek                         Salon       Hustle & Flow
# 4             Jami Bernard           New York Daily News       Hustle & Flow
# ...                    ...                           ...                 ...
# 213570      John Patterson                   L.A. Weekly  The Quiet American
# 213571          Rick Groen  The Globe and Mail (Toronto)  The Quiet American
# 213572    Jonathan Foreman                 New York Post  The Quiet American
# 213573        Jami Bernard           New York Daily News  The Quiet American
# 213574   Stanley Kauffmann              The New Republic  The Quiet American
#
#        review_date  individual_meta_score  \
# ...
